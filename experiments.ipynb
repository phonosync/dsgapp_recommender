# %%
import os
from pathlib import Path
import pandas as pd
from surprise import BaselineOnly, Dataset, Reader, accuracy, SVD, KNNBasic
from surprise.dump import dump, load
from surprise.model_selection import train_test_split

import surprise_utils as s_utils

# %%
# path to dataset file
file_path = os.path.expanduser("~/.surprise_data/ml-100k/ml-100k/u.data")

# file_path = "recommender.csv"
file_path = Path(r"C:\\Users\doem\projects\dsgapps\test data\recommender\collab filtering Restaurant Recommender.csv")

# %%
df = pd.read_csv(file_path, delimiter=';')

# A reader is still needed but only the rating_scale param is requiered.
reader = Reader(rating_scale=(1, 5))

# The columns must correspond to user id, item id and ratings (in that order).
data = Dataset.load_from_df(df[["USER_ID", "OSM_ID", "RATING"]], reader)

# %%
data

# %%
# sample random trainset and testset
# test set is made of 25% of the ratings.
trainset, testset = train_test_split(data, test_size=0.2)

# %%
trainset

# %%
sim_options = {
    "name": "cosine",
    "user_based": False,  # compute  similarities between items
}
algo = KNNBasic(sim_options=sim_options)

# Train the algorithm on the trainset, and predict ratings for the testset
algo.fit(trainset)
predictions = algo.test(testset)
# Then compute RMSE
accuracy.rmse(predictions)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# RMSE: 1.1081
# 1.1081254449193887

# %%
predictions
# Out:
# [Prediction(uid='4-Team Rick', iid=8199027204, r_ui=5.0, est=3.0, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='6-Team21', iid=359695274, r_ui=3.0, est=3.3275786826695875, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='6-Kool and the floating point', iid=4095987436, r_ui=3.0, est=3.725303201689979, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='3-Kool and the floating point', iid=247766478, r_ui=2.0, est=3.0000000000000004, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='6-Data in Destiny', iid=9813646886, r_ui=4.0, est=4.6640378824896205, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='U16-Data Bunny', iid=359687037, r_ui=4.0, est=3.745929212426745, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='115-S3J', iid=282655574, r_ui=3.0, est=3.000169801133423, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='8-Team Rick', iid=2795232150, r_ui=3.0, est=3.1669463158342563, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='108-S3J', iid=2649686873, r_ui=4.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='3-Data in Destiny', iid=359694784, r_ui=5.0, est=3.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='100-S3J', iid=277746978, r_ui=5.0, est=5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='105-S3J', iid=4109460415, r_ui=5.0, est=3.828285852896235, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='8-Team Rick', iid=359683717, r_ui=4.0, est=4.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='103-S3J', iid=9655661536, r_ui=4.0, est=3.690983005625053, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='22-Data in Destiny', iid=359685942, r_ui=5.0, est=3.5980392156862746, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='12-Team21', iid=4127859153, r_ui=4.0, est=2.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='2-Kool and the floating point', iid=4095400192, r_ui=1.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='U19-Data Bunny', iid=359687037, r_ui=4.0, est=4.024726389861141, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='19-Data in Destiny', iid=282655581, r_ui=4.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='7-Data in Destiny', iid=712608636, r_ui=3.0, est=4.506184291579231, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='101-S3J', iid=4985409623, r_ui=2.0, est=2.7459320097282696, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='U9-Data Bunny', iid=380488748, r_ui=4.0, est=4.489598525151345, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='4-Kool and the floating point', iid=4095987426, r_ui=4.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='3-Data in Destiny', iid=8128785390, r_ui=4.0, est=4.743568421676104, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='105-S3J', iid=2424718821, r_ui=1.0, est=3.8333333333333335, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='8-Kool and the floating point', iid=4095987419, r_ui=5.0, est=3.2488514440330443, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='110-S3J', iid=2424723261, r_ui=3.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='U17-Data Bunny', iid=763523652, r_ui=4.0, est=4.714285714285714, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='5-Team Rick', iid=359695274, r_ui=2.0, est=3.4993836085451338, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='16-Team21', iid=4127859153, r_ui=4.0, est=4.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='7-Data in Destiny', iid=7826688994, r_ui=3.0, est=4.496904121098006, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='U4-Data Bunny', iid=9655661536, r_ui=5.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='15-Data in Destiny', iid=359692293, r_ui=4.0, est=3.5097026720776707, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='2-Data in Destiny', iid=359695274, r_ui=5.0, est=4.0, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='18-Team Rick', iid=9581108183, r_ui=3.0, est=3.322702433384966, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='102-S3J', iid=277746978, r_ui=3.0, est=4.0, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='102-S3J', iid=65619602, r_ui=5.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='3-Team Rick', iid=39666027, r_ui=4.0, est=4.000000000000001, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='5-Data in Destiny', iid=7826688994, r_ui=5.0, est=4.289760183731305, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='20-Team Rick', iid=353186982, r_ui=3.0, est=4.346085235685371, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='6-Kool and the floating point', iid=4109460415, r_ui=2.0, est=3.7339004023707303, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='9-Team Rick', iid=359686907, r_ui=3.0, est=3.006515282229218, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='U10-Data Bunny', iid=4095987432, r_ui=3.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='107-S3J', iid=854335396, r_ui=3.0, est=3.6666666666666665, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='10-Team Rick', iid=498891528, r_ui=5.0, est=2.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='5-Team Rick', iid=247766478, r_ui=5.0, est=3.3756601065846237, details={'actual_k': 11, 'was_impossible': False}),
#  Prediction(uid='U16-Data Bunny', iid=561504426, r_ui=1.0, est=4.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='2-Kool and the floating point', iid=4095987422, r_ui=5.0, est=2.857142857142857, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='10-Team Rick', iid=4095987428, r_ui=4.0, est=3.0, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='11-Team21', iid=282655581, r_ui=4.0, est=3.4979507852517946, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='U4-Data Bunny', iid=353186982, r_ui=4.0, est=1, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='19-Data in Destiny', iid=1519474203, r_ui=3.0, est=3.3220678047912084, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='5-Team21', iid=4127859153, r_ui=3.0, est=3.6643168222252784, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='10-Kool and the floating point', iid=574685031, r_ui=2.0, est=3.41003721517881, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='114-S3J', iid=247766478, r_ui=1.0, est=3.3642328977082805, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='116-S3J', iid=282655574, r_ui=4.0, est=3.127267007282358, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='11-Kool and the floating point', iid=534878149, r_ui=4.0, est=4.505083099145056, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='11-Team Rick', iid=593846241, r_ui=4.0, est=3.6666666666666665, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='U3-Data Bunny', iid=2466736061, r_ui=4.0, est=3.6613220689033166, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='7-Data in Destiny', iid=7439496294, r_ui=4.0, est=4.671212650850196, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='19-Team Rick', iid=471628000, r_ui=3.0, est=3.244816285461566, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='4-Data in Destiny', iid=712608636, r_ui=4.0, est=4.508199038514408, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='7-Data in Destiny', iid=4095400151, r_ui=5.0, est=4.61770794941782, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='101-S3J', iid=4868065118, r_ui=5.0, est=3.5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='16-Team21', iid=5109346567, r_ui=4.0, est=4.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='1-Kool and the floating point', iid=382989332, r_ui=1.0, est=2.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='11-Data in Destiny', iid=247766478, r_ui=4.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='102-S3J', iid=9655661536, r_ui=5.0, est=3.5, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='15-Data in Destiny', iid=246249861, r_ui=4.0, est=3.6666666666666665, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='2-Team21', iid=359695274, r_ui=5.0, est=3.7983487838504604, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='16-Team Rick', iid=359686907, r_ui=3.0, est=3.0122364046046086, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='10-Kool and the floating point', iid=4095987428, r_ui=5.0, est=3.1440146873766674, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='U3-Data Bunny', iid=4358977790, r_ui=4.0, est=4.0, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='2-Kool and the floating point', iid=564888543, r_ui=5.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='8-Team Rick', iid=1519474203, r_ui=3.0, est=2.9155286760458354, details={'actual_k': 12, 'was_impossible': False}),
#  Prediction(uid='20-Team Rick', iid=9581108183, r_ui=4.0, est=4.327269263700098, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='U8-Data Bunny', iid=256866280, r_ui=5.0, est=2.50757595082502, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='U10-Data Bunny', iid=472774192, r_ui=5.0, est=2.9867697606986647, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='1-Kool and the floating point', iid=359692073, r_ui=4.0, est=3.6666666666666665, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='13-Team Rick', iid=471628000, r_ui=2.0, est=3.326104252031289, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='110-S3J', iid=246249861, r_ui=4.0, est=3.6489797157936206, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='15-Team Rick', iid=353186982, r_ui=4.0, est=4.253557540391686, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='U18-Data Bunny', iid=6223030513, r_ui=5.0, est=3.6707624695762706, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='U15-Data Bunny', iid=282655581, r_ui=5.0, est=4.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='14-Data in Destiny', iid=2570468652, r_ui=5.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='U19-Data Bunny', iid=471628000, r_ui=3.0, est=4.021305370219777, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='12-Kool and the floating point', iid=380488748, r_ui=4.0, est=4.503539923627676, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='21-Data in Destiny', iid=4358977790, r_ui=4.0, est=3.5058754168514206, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='2-Team Rick', iid=2795251539, r_ui=4.0, est=4.6, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='4-Team21', iid=282655581, r_ui=5.0, est=4.0, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='18-Data in Destiny', iid=471628000, r_ui=4.0, est=4.334137383681958, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='U18-Data Bunny', iid=2955638928, r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='7-Kool and the floating point', iid=277746978, r_ui=4.0, est=3.761811112680071, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='103-S3J', iid=39666027, r_ui=3.0, est=3.655124665034454, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='5-Team21', iid=1519474203, r_ui=3.0, est=3.6661337677667034, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='1-Team Rick', iid=2457539648, r_ui=4.0, est=3.25, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='8-Team Rick', iid=359686907, r_ui=3.0, est=3.0, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='2-Team Rick', iid=7439496294, r_ui=3.0, est=4.611101566392438, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='18-Data in Destiny', iid=247766478, r_ui=5.0, est=4.50561797752809, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='1-Data in Destiny', iid=534917835, r_ui=4.0, est=3.8333333333333335, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='6-Data in Destiny', iid=9880301426, r_ui=4.0, est=4.656473588717122, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='18-Data in Destiny', iid=405400186, r_ui=4.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='U14-Data Bunny', iid=270908998, r_ui=3.0, est=2.9999999999999996, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='10-Team21', iid=359695274, r_ui=3.0, est=4.5038463814561585, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='U14-Data Bunny', iid=353186982, r_ui=2.0, est=3.3333333333333335, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='106-S3J', iid=4095987426, r_ui=4.0, est=4.331092379908058, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='U5-Data Bunny', iid=659475608, r_ui=4.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='5-Team Rick', iid=359686907, r_ui=4.0, est=2.622380867721261, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='6-Team21', iid=1519474203, r_ui=4.0, est=3.506825620262373, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='20-Data in Destiny', iid=4358977790, r_ui=4.0, est=3.3859670860248268, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='1-Team21', iid=359695274, r_ui=4.0, est=3.0, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='22-Data in Destiny', iid=1519474203, r_ui=3.0, est=3.5978412350323827, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='5-Team Rick', iid=4985409623, r_ui=3.0, est=3.1275279227866015, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='3-Team Rick', iid=9581108183, r_ui=3.0, est=4.339071344042179, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='U16-Data Bunny', iid=282655574, r_ui=4.0, est=3.797722236223085, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='113-S3J', iid=380488748, r_ui=4.0, est=2.5053372991632625, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='101-S3J', iid=115570125, r_ui=3.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='17-Data in Destiny', iid=4095401193, r_ui=5.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='8-Kool and the floating point', iid=359701183, r_ui=4.0, est=3.269774604435862, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='5-Team Rick', iid=574685031, r_ui=3.0, est=3.3376408318556985, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='23-Data in Destiny', iid=3483494147, r_ui=3.0, est=3.490332006371675, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='2-Team Rick', iid=9581108183, r_ui=4.0, est=4.603494397819738, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='5-Team Rick', iid=7439496294, r_ui=3.0, est=3.204604795643481, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='U18-Data Bunny', iid=359687975, r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='9-Team21', iid=5109346567, r_ui=5.0, est=4.0, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='7-Team Rick', iid=4125136764, r_ui=4.0, est=4.714285714285714, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='5-Data in Destiny', iid=8519878955, r_ui=4.0, est=4.166666666666667, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='101-S3J', iid=548920489, r_ui=4.0, est=2.9973388339041263, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='17-Data in Destiny', iid=359692293, r_ui=5.0, est=4.666666666666667, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='14-Data in Destiny', iid=359687975, r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='104-S3J', iid=353186982, r_ui=1.0, est=3.1738828636781493, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='9-Team21', iid=9813646886, r_ui=4.0, est=4.0, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='113-S3J', iid=2466736061, r_ui=3.0, est=2.5112843651118064, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='U3-Data Bunny', iid=4417689793, r_ui=5.0, est=3.665979138593822, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='6-Data in Destiny', iid=564670042, r_ui=5.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='5-Kool and the floating point', iid=4109460415, r_ui=3.0, est=4.163105636021046, details={'actual_k': 9, 'was_impossible': False}),
#  Prediction(uid='7-Kool and the floating point', iid=564888514, r_ui=3.0, est=3.811785640396291, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='113-S3J', iid=6223030513, r_ui=5.0, est=2.510011676384879, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='U19-Data Bunny', iid=386536801, r_ui=4.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='4-Team Rick', iid=359687037, r_ui=4.0, est=3.821422592441474, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='101-S3J', iid=561524250, r_ui=5.0, est=3.0, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='8-Data in Destiny', iid=7439496294, r_ui=4.0, est=3.5725495162364163, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='22-Data in Destiny', iid=3483494147, r_ui=3.0, est=3.5905585730812217, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='10-Data in Destiny', iid=7826688994, r_ui=3.0, est=4.127217816344732, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='4-Data in Destiny', iid=4095400151, r_ui=5.0, est=4.445619769130456, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='2-Data in Destiny', iid=534878149, r_ui=3.0, est=4.0, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='15-Data in Destiny', iid=47162000, r_ui=4.0, est=3.0, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='U13-Data Bunny', iid=380488748, r_ui=3.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='5-Data in Destiny', iid=712608636, r_ui=5.0, est=4.333729290036562, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='U4-Data Bunny', iid=3483494147, r_ui=5.0, est=5, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='U8-Data Bunny', iid=1479407508, r_ui=4.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='1-Data in Destiny', iid=359683717, r_ui=3.0, est=3.8333333333333335, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='U16-Data Bunny', iid=359690871, r_ui=4.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='6-Kool and the floating point', iid=4095987419, r_ui=5.0, est=3.7146608350349304, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='11-Kool and the floating point', iid=359687037, r_ui=3.0, est=3.3370514457077154, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='116-S3J', iid=534917835, r_ui=4.0, est=3.1616716147897286, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='U16-Data Bunny', iid=246249861, r_ui=2.0, est=4.0, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='105-S3J', iid=4095987428, r_ui=3.0, est=3.668490392519565, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='17-Team21', iid=4456693165, r_ui=4.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='8-Data in Destiny', iid=9813646886, r_ui=5.0, est=3.4253272775928982, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='16-Data in Destiny', iid=386536801, r_ui=4.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='9-Team Rick', iid=359687037, r_ui=4.0, est=3.2225040041994357, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='9-Data in Destiny', iid=7826688994, r_ui=3.0, est=3.8648635968931218, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='18-Team Rick', iid=359686907, r_ui=4.0, est=3.334084112638942, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='20-Data in Destiny', iid=8199027204, r_ui=5.0, est=2.9972714412709185, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='17-Team Rick', iid=471628000, r_ui=5.0, est=3.5133088092077025, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='113-S3J', iid=534917835, r_ui=5.0, est=2.5143029632834235, details={'actual_k': 6, 'was_impossible': False}),
#  Prediction(uid='10-Team Rick', iid=1519474203, r_ui=3.0, est=3.8044722530158293, details={'actual_k': 5, 'was_impossible': False}),
#  Prediction(uid='7-Team Rick', iid=282655581, r_ui=5.0, est=4.714285714285714, details={'actual_k': 7, 'was_impossible': False}),
#  Prediction(uid='9-Team21', iid=4095400186, r_ui=4.0, est=4.0, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='4-Team Rick', iid=7439496294, r_ui=2.0, est=4.2558089359494415, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='13-Team Rick', iid=353186982, r_ui=4.0, est=3.325818438311837, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='8-Team Rick', iid=560156308, r_ui=4.0, est=3.6666666666666665, details={'actual_k': 3, 'was_impossible': False}),
#  Prediction(uid='108-S3J', iid=4143671996, r_ui=3.0, est=3.7045454545454546, details={'was_impossible': True, 'reason': 'Not enough neighbors.'}),
#  Prediction(uid='7-Data in Destiny', iid=4095400186, r_ui=5.0, est=4.502905306099496, details={'actual_k': 4, 'was_impossible': False}),
#  Prediction(uid='114-S3J', iid=3124969719, r_ui=3.0, est=3.3871418571451484, details={'actual_k': 8, 'was_impossible': False}),
#  Prediction(uid='102-S3J', iid=561524250, r_ui=4.0, est=3.5, details={'actual_k': 2, 'was_impossible': False})]

# %%
algo=SVD()
# Train the algorithm on the trainset, and predict ratings for the testset
algo.fit(trainset)
predictions = algo.test(testset)
# Then compute RMSE
accuracy.rmse(predictions)
# Out:
# RMSE: 0.9088
# 0.9087707776624142

# %%
# dump('bla', predictions=None, algo=algo, verbose=0)
# grmpf = load('bla')

# %%
predictions
# Out:
# [Prediction(uid='U5-Data Bunny', iid=659475608, r_ui=4.0, est=4.004185641660566, details={'was_impossible': False}),
#  Prediction(uid='6-Kool and the floating point', iid=564888514, r_ui=4.0, est=3.8048099022841475, details={'was_impossible': False}),
#  Prediction(uid='10-Kool and the floating point', iid=7503079102, r_ui=3.0, est=3.5231903624904954, details={'was_impossible': False}),
#  Prediction(uid='U16-Data Bunny', iid=43011471, r_ui=4.0, est=3.195964086010014, details={'was_impossible': False}),
#  Prediction(uid='U12-Data Bunny', iid=256866280, r_ui=5.0, est=3.8616633685575374, details={'was_impossible': False}),
#  Prediction(uid='108-S3J', iid=561504426, r_ui=3.0, est=3.27854248466876, details={'was_impossible': False}),
#  Prediction(uid='115-S3J', iid=6223030513, r_ui=5.0, est=3.521205219443351, details={'was_impossible': False}),
#  Prediction(uid='12-Kool and the floating point', iid=359687037, r_ui=3.0, est=4.219129540768112, details={'was_impossible': False}),
#  Prediction(uid='9-Team Rick', iid=1519474203, r_ui=3.0, est=3.530828827085279, details={'was_impossible': False}),
#  Prediction(uid='3-Team21', iid=359695274, r_ui=5.0, est=3.9276358173885315, details={'was_impossible': False}),
#  Prediction(uid='10-Kool and the floating point', iid=4816412579, r_ui=5.0, est=3.5197522955900262, details={'was_impossible': False}),
#  Prediction(uid='U15-Data Bunny', iid=282655574, r_ui=3.0, est=3.7189081087595044, details={'was_impossible': False}),
#  Prediction(uid='13-Team Rick', iid=76852026291, r_ui=4.0, est=3.705717540184578, details={'was_impossible': False}),
#  Prediction(uid='U4-Data Bunny', iid=7439496294, r_ui=1.0, est=3.8642159393725004, details={'was_impossible': False}),
#  Prediction(uid='18-Data in Destiny', iid=380094845, r_ui=4.0, est=4.128040119050934, details={'was_impossible': False}),
#  Prediction(uid='12-Team Rick', iid=7503079102, r_ui=3.0, est=4.038865098820536, details={'was_impossible': False}),
#  Prediction(uid='U15-Data Bunny', iid=43011471, r_ui=3.0, est=3.503700244775937, details={'was_impossible': False}),
#  Prediction(uid='107-S3J', iid=854335396, r_ui=3.0, est=3.2197547488847973, details={'was_impossible': False}),
#  Prediction(uid='19-Team Rick', iid=9581108183, r_ui=3.0, est=3.537155592694059, details={'was_impossible': False}),
#  Prediction(uid='14-Team Rick', iid=76852026291, r_ui=4.0, est=4.015272902324025, details={'was_impossible': False}),
#  Prediction(uid='108-S3J', iid=731833436, r_ui=3.0, est=3.8611087603574545, details={'was_impossible': False}),
#  Prediction(uid='U7-Data Bunny', iid=4095400186, r_ui=5.0, est=4.531460859108714, details={'was_impossible': False}),
#  Prediction(uid='U9-Data Bunny', iid=380488748, r_ui=4.0, est=4.3903105706599295, details={'was_impossible': False}),
#  Prediction(uid='2-Team21', iid=703057903, r_ui=3.0, est=3.592541034302999, details={'was_impossible': False}),
#  Prediction(uid='20-Data in Destiny', iid=380094845, r_ui=4.0, est=3.9258740955498728, details={'was_impossible': False}),
#  Prediction(uid='11-Team21', iid=282655581, r_ui=4.0, est=4.225185369960557, details={'was_impossible': False}),
#  Prediction(uid='112-S3J', iid=5144542839, r_ui=3.0, est=3.671588986366617, details={'was_impossible': False}),
#  Prediction(uid='14-Team Rick', iid=353186982, r_ui=4.0, est=3.5435856300235016, details={'was_impossible': False}),
#  Prediction(uid='116-S3J', iid=472774192, r_ui=3.0, est=3.869078123739632, details={'was_impossible': False}),
#  Prediction(uid='U2-Data Bunny', iid=353186982, r_ui=1.0, est=3.524611465046949, details={'was_impossible': False}),
#  Prediction(uid='4-Team21', iid=359695274, r_ui=4.0, est=4.11741805463399, details={'was_impossible': False}),
#  Prediction(uid='16-Data in Destiny', iid=41217199, r_ui=4.0, est=3.687090537440542, details={'was_impossible': False}),
#  Prediction(uid='7-Data in Destiny', iid=7439496294, r_ui=4.0, est=4.225596151220224, details={'was_impossible': False}),
#  Prediction(uid='U17-Data Bunny', iid=6223030513, r_ui=5.0, est=4.462897473367505, details={'was_impossible': False}),
#  Prediction(uid='12-Team Rick', iid=1479407508, r_ui=5.0, est=4.227282808041476, details={'was_impossible': False}),
#  Prediction(uid='11-Kool and the floating point', iid=7503079102, r_ui=3.0, est=3.7436911061770726, details={'was_impossible': False}),
#  Prediction(uid='12-Kool and the floating point', iid=2466736061, r_ui=4.0, est=4.118115782291297, details={'was_impossible': False}),
#  Prediction(uid='8-Team21', iid=1519474203, r_ui=3.0, est=3.8844177348284727, details={'was_impossible': False}),
#  Prediction(uid='1-Team Rick', iid=353186982, r_ui=3.0, est=3.277967209575046, details={'was_impossible': False}),
#  Prediction(uid='12-Team Rick', iid=282655574, r_ui=4.0, est=3.9081870968254493, details={'was_impossible': False}),
#  Prediction(uid='111-S3J', iid=359694784, r_ui=3.0, est=4.2460668419478615, details={'was_impossible': False}),
#  Prediction(uid='104-S3J', iid=6223030513, r_ui=3.0, est=3.8768778593303126, details={'was_impossible': False}),
#  Prediction(uid='1-Team21', iid=8199027204, r_ui=3.0, est=3.7737425290431, details={'was_impossible': False}),
#  Prediction(uid='16-Team Rick', iid=76852026291, r_ui=2.0, est=3.7124168477523325, details={'was_impossible': False}),
#  Prediction(uid='4-Team Rick', iid=2466736061, r_ui=3.0, est=3.943421467588674, details={'was_impossible': False}),
#  Prediction(uid='18-Data in Destiny', iid=2466736061, r_ui=4.0, est=4.115233083767771, details={'was_impossible': False}),
#  Prediction(uid='9-Team21', iid=4095400186, r_ui=4.0, est=3.9678644225322826, details={'was_impossible': False}),
#  Prediction(uid='20-Team Rick', iid=471628000, r_ui=4.0, est=3.6921904394856067, details={'was_impossible': False}),
#  Prediction(uid='U5-Data Bunny', iid=256866280, r_ui=4.0, est=4.140649067144969, details={'was_impossible': False}),
#  Prediction(uid='104-S3J', iid=2424718821, r_ui=1.0, est=3.4255013866643584, details={'was_impossible': False}),
#  Prediction(uid='6-Data in Destiny', iid=564670042, r_ui=5.0, est=3.6965206224268825, details={'was_impossible': False}),
#  Prediction(uid='4-Kool and the floating point', iid=4395329792, r_ui=3.0, est=3.228430144514353, details={'was_impossible': False}),
#  Prediction(uid='15-Team21', iid=4127859153, r_ui=4.0, est=3.72608270993877, details={'was_impossible': False}),
#  Prediction(uid='111-S3J', iid=2466736061, r_ui=3.0, est=3.8180310190755122, details={'was_impossible': False}),
#  Prediction(uid='22-Data in Destiny', iid=359685942, r_ui=5.0, est=3.6464198709730713, details={'was_impossible': False}),
#  Prediction(uid='U9-Data Bunny', iid=270908998, r_ui=5.0, est=4.4692925209046095, details={'was_impossible': False}),
#  Prediction(uid='17-Data in Destiny', iid=534878149, r_ui=5.0, est=4.145020153201753, details={'was_impossible': False}),
#  Prediction(uid='U4-Data Bunny', iid=353186982, r_ui=4.0, est=3.6494914472930136, details={'was_impossible': False}),
#  Prediction(uid='14-Team Rick', iid=471628000, r_ui=3.0, est=3.5698492650936586, details={'was_impossible': False}),
#  Prediction(uid='7-Team Rick', iid=763523652, r_ui=4.0, est=4.126653039200348, details={'was_impossible': False}),
#  Prediction(uid='10-Data in Destiny', iid=2424724937, r_ui=2.0, est=4.059246503082317, details={'was_impossible': False}),
#  Prediction(uid='9-Kool and the floating point', iid=4095400186, r_ui=4.0, est=3.8887019988136826, details={'was_impossible': False}),
#  Prediction(uid='U12-Data Bunny', iid=246253651, r_ui=4.0, est=3.769639572017036, details={'was_impossible': False}),
#  Prediction(uid='4-Team21', iid=4127859153, r_ui=4.0, est=3.934171734355484, details={'was_impossible': False}),
#  Prediction(uid='112-S3J', iid=270908998, r_ui=4.0, est=3.7908287682689057, details={'was_impossible': False}),
#  Prediction(uid='U14-Data Bunny', iid=270908998, r_ui=3.0, est=3.6057963732365947, details={'was_impossible': False}),
#  Prediction(uid='3-Team21', iid=703057903, r_ui=5.0, est=3.754664343897384, details={'was_impossible': False}),
#  Prediction(uid='114-S3J', iid=472774192, r_ui=3.0, est=3.3355715099198497, details={'was_impossible': False}),
#  Prediction(uid='104-S3J', iid=472774192, r_ui=3.0, est=3.602988396031492, details={'was_impossible': False}),
#  Prediction(uid='10-Data in Destiny', iid=9880301426, r_ui=3.0, est=4.14415855575664, details={'was_impossible': False}),
#  Prediction(uid='14-Data in Destiny', iid=2570468652, r_ui=5.0, est=4.094405367852663, details={'was_impossible': False}),
#  Prediction(uid='14-Team Rick', iid=359686907, r_ui=3.0, est=3.7806470249558624, details={'was_impossible': False}),
#  Prediction(uid='U4-Data Bunny', iid=574685031, r_ui=5.0, est=3.68508677991173, details={'was_impossible': False}),
#  Prediction(uid='9-Team21', iid=5109346567, r_ui=5.0, est=3.855403143461231, details={'was_impossible': False}),
#  Prediction(uid='116-S3J', iid=282655574, r_ui=4.0, est=3.2959765881875844, details={'was_impossible': False}),
#  Prediction(uid='U2-Data Bunny', iid=9655661536, r_ui=2.0, est=3.8333731606658437, details={'was_impossible': False}),
#  Prediction(uid='5-Team Rick', iid=3483494147, r_ui=3.0, est=2.999020483465128, details={'was_impossible': False}),
#  Prediction(uid='7-Kool and the floating point', iid=4095400186, r_ui=4.0, est=3.9778102402287847, details={'was_impossible': False}),
#  Prediction(uid='114-S3J', iid=246249861, r_ui=2.0, est=3.1780112983937303, details={'was_impossible': False}),
#  Prediction(uid='101-S3J', iid=561524250, r_ui=5.0, est=3.5774855336503695, details={'was_impossible': False}),
#  Prediction(uid='12-Kool and the floating point', iid=7503079102, r_ui=5.0, est=3.9561924084506157, details={'was_impossible': False}),
#  Prediction(uid='U1-Data Bunny', iid=8128785390, r_ui=2.0, est=3.4667658646718995, details={'was_impossible': False}),
#  Prediction(uid='9-Kool and the floating point', iid=6223030513, r_ui=5.0, est=3.8788913434414365, details={'was_impossible': False}),
#  Prediction(uid='9-Data in Destiny', iid=712608636, r_ui=3.0, est=3.823281233400239, details={'was_impossible': False}),
#  Prediction(uid='2-Data in Destiny', iid=359683717, r_ui=3.0, est=3.920901865369496, details={'was_impossible': False}),
#  Prediction(uid='20-Team21', iid=8199027204, r_ui=4.0, est=3.7032597365378734, details={'was_impossible': False}),
#  Prediction(uid='11-Kool and the floating point', iid=8128785390, r_ui=2.0, est=3.525080123695106, details={'was_impossible': False}),
#  Prediction(uid='U16-Data Bunny', iid=472774192, r_ui=4.0, est=3.7770414447711866, details={'was_impossible': False}),
#  Prediction(uid='8-Data in Destiny', iid=7439496294, r_ui=4.0, est=3.5519257578888563, details={'was_impossible': False}),
#  Prediction(uid='114-S3J', iid=380488748, r_ui=5.0, est=3.315587217662561, details={'was_impossible': False}),
#  Prediction(uid='3-Data in Destiny', iid=4109460415, r_ui=5.0, est=3.7458605769168236, details={'was_impossible': False}),
#  Prediction(uid='113-S3J', iid=6223030513, r_ui=5.0, est=3.8314783399071084, details={'was_impossible': False}),
#  Prediction(uid='3-Kool and the floating point', iid=359688178, r_ui=4.0, est=3.306538708631484, details={'was_impossible': False}),
#  Prediction(uid='100-S3J', iid=561524250, r_ui=5.0, est=3.98968919442219, details={'was_impossible': False}),
#  Prediction(uid='9-Kool and the floating point', iid=2466736061, r_ui=4.0, est=3.6613589715573123, details={'was_impossible': False}),
#  Prediction(uid='100-S3J', iid=6504247617, r_ui=3.0, est=4.031135460949735, details={'was_impossible': False}),
#  Prediction(uid='104-S3J', iid=4095400186, r_ui=3.0, est=3.6248082593081143, details={'was_impossible': False}),
#  Prediction(uid='8-Team Rick', iid=9655661531, r_ui=2.0, est=3.4216254604820366, details={'was_impossible': False}),
#  Prediction(uid='101-S3J', iid=4095987428, r_ui=2.0, est=4.0150867537649955, details={'was_impossible': False}),
#  Prediction(uid='7-Team21', iid=4127859153, r_ui=4.0, est=3.920991218568937, details={'was_impossible': False}),
#  Prediction(uid='15-Data in Destiny', iid=47162000, r_ui=4.0, est=3.7274600373760363, details={'was_impossible': False}),
#  Prediction(uid='9-Data in Destiny', iid=534876365, r_ui=3.0, est=3.7568713440905768, details={'was_impossible': False}),
#  Prediction(uid='7-Team Rick', iid=359686638, r_ui=5.0, est=4.250972478363887, details={'was_impossible': False}),
#  Prediction(uid='U5-Data Bunny', iid=359694784, r_ui=5.0, est=4.213136498013448, details={'was_impossible': False}),
#  Prediction(uid='5-Team Rick', iid=359695274, r_ui=2.0, est=3.7207261323220067, details={'was_impossible': False}),
#  Prediction(uid='114-S3J', iid=6223030513, r_ui=5.0, est=3.608733088345813, details={'was_impossible': False}),
#  Prediction(uid='3-Data in Destiny', iid=7826688994, r_ui=5.0, est=3.6305373218306114, details={'was_impossible': False}),
#  Prediction(uid='2-Team Rick', iid=2795251539, r_ui=4.0, est=4.100540484374868, details={'was_impossible': False}),
#  Prediction(uid='2-Data in Destiny', iid=359686638, r_ui=4.0, est=4.046325094737311, details={'was_impossible': False}),
#  Prediction(uid='107-S3J', iid=4095987422, r_ui=5.0, est=3.8979718408326165, details={'was_impossible': False}),
#  Prediction(uid='1-Team21', iid=359695274, r_ui=4.0, est=3.885131148761638, details={'was_impossible': False}),
#  Prediction(uid='2-Data in Destiny', iid=534917835, r_ui=4.0, est=3.946624629488429, details={'was_impossible': False}),
#  Prediction(uid='101-S3J', iid=277746978, r_ui=3.0, est=3.578342080493787, details={'was_impossible': False}),
#  Prediction(uid='6-Kool and the floating point', iid=359693315, r_ui=3.0, est=2.8108507714245956, details={'was_impossible': False}),
#  Prediction(uid='104-S3J', iid=4095400191, r_ui=3.0, est=3.1773233162520635, details={'was_impossible': False}),
#  Prediction(uid='4-Data in Destiny', iid=8128785390, r_ui=4.0, est=4.042380041256258, details={'was_impossible': False}),
#  Prediction(uid='114-S3J', iid=2466736061, r_ui=3.0, est=3.603015006045113, details={'was_impossible': False}),
#  Prediction(uid='4-Data in Destiny', iid=8519878955, r_ui=3.0, est=3.914662871543973, details={'was_impossible': False}),
#  Prediction(uid='U19-Data Bunny', iid=359691092, r_ui=4.0, est=3.868399110383821, details={'was_impossible': False}),
#  Prediction(uid='U10-Data Bunny', iid=9655661535, r_ui=3.0, est=3.713371396014506, details={'was_impossible': False}),
#  Prediction(uid='11-Team Rick', iid=359686907, r_ui=3.0, est=4.021810409829128, details={'was_impossible': False}),
#  Prediction(uid='12-Kool and the floating point', iid=135915056, r_ui=5.0, est=3.9561924084506157, details={'was_impossible': False}),
#  Prediction(uid='3-Team Rick', iid=4358977790, r_ui=5.0, est=3.6497909319826873, details={'was_impossible': False}),
#  Prediction(uid='U6-Data Bunny', iid=7992692128, r_ui=5.0, est=4.301032298184535, details={'was_impossible': False}),
#  Prediction(uid='19-Data in Destiny', iid=1519474203, r_ui=3.0, est=3.6223796886647266, details={'was_impossible': False}),
#  Prediction(uid='6-Kool and the floating point', iid=277746978, r_ui=4.0, est=3.6889426182556653, details={'was_impossible': False}),
#  Prediction(uid='12-Team21', iid=359695274, r_ui=2.0, est=4.161696751724358, details={'was_impossible': False}),
#  Prediction(uid='U17-Data Bunny', iid=763523652, r_ui=4.0, est=4.121080426824136, details={'was_impossible': False}),
#  Prediction(uid='14-Data in Destiny', iid=359691092, r_ui=4.0, est=4.146356139388117, details={'was_impossible': False}),
#  Prediction(uid='8-Team Rick', iid=3483494147, r_ui=3.0, est=3.247378606927331, details={'was_impossible': False}),
#  Prediction(uid='108-S3J', iid=359686907, r_ui=3.0, est=3.6850521744322804, details={'was_impossible': False}),
#  Prediction(uid='3-Team21', iid=4127859153, r_ui=4.0, est=3.8314378939144267, details={'was_impossible': False}),
#  Prediction(uid='11-Kool and the floating point', iid=471628000, r_ui=2.0, est=3.51482363721561, details={'was_impossible': False}),
#  Prediction(uid='9-Data in Destiny', iid=2424724937, r_ui=2.0, est=3.8339706147233104, details={'was_impossible': False}),
#  Prediction(uid='105-S3J', iid=2424718821, r_ui=1.0, est=3.5406792851642477, details={'was_impossible': False}),
#  Prediction(uid='U11-Data Bunny', iid=359691092, r_ui=5.0, est=3.9752054366993903, details={'was_impossible': False}),
#  Prediction(uid='5-Team Rick', iid=4127859153, r_ui=3.0, est=3.2467135847383486, details={'was_impossible': False}),
#  Prediction(uid='9-Team Rick', iid=359686907, r_ui=3.0, est=3.674302689111335, details={'was_impossible': False}),
#  Prediction(uid='U20-Data Bunny', iid=359690786, r_ui=4.0, est=3.757250559189612, details={'was_impossible': False}),
#  Prediction(uid='1-Data in Destiny', iid=2424724937, r_ui=3.0, est=3.754019051696568, details={'was_impossible': False}),
#  Prediction(uid='106-S3J', iid=472774192, r_ui=4.0, est=4.0486148135486015, details={'was_impossible': False}),
#  Prediction(uid='4-Data in Destiny', iid=1519474203, r_ui=4.0, est=4.223072046870893, details={'was_impossible': False}),
#  Prediction(uid='15-Team21', iid=359695274, r_ui=5.0, est=4.161569199415703, details={'was_impossible': False}),
#  Prediction(uid='1-Team21', iid=4095400186, r_ui=3.0, est=3.869584781736317, details={'was_impossible': False}),
#  Prediction(uid='3-Team21', iid=1519474203, r_ui=4.0, est=3.8850680365658072, details={'was_impossible': False}),
#  Prediction(uid='U7-Data Bunny', iid=564888543, r_ui=5.0, est=4.61405424859896, details={'was_impossible': False}),
#  Prediction(uid='2-Team21', iid=282655581, r_ui=4.0, est=4.117885934010465, details={'was_impossible': False}),
#  Prediction(uid='110-S3J', iid=256866280, r_ui=5.0, est=3.915392869689416, details={'was_impossible': False}),
#  Prediction(uid='U16-Data Bunny', iid=359694784, r_ui=4.0, est=3.7982552072420317, details={'was_impossible': False}),
#  Prediction(uid='6-Team Rick', iid=2493971952, r_ui=4.0, est=3.600519197360637, details={'was_impossible': False}),
#  Prediction(uid='5-Team Rick', iid=4456693165, r_ui=3.0, est=3.533028203804048, details={'was_impossible': False}),
#  Prediction(uid='15-Data in Destiny', iid=246249861, r_ui=4.0, est=3.33926521134475, details={'was_impossible': False}),
#  Prediction(uid='103-S3J', iid=9655661536, r_ui=4.0, est=4.0279138946763196, details={'was_impossible': False}),
#  Prediction(uid='5-Data in Destiny', iid=1519474203, r_ui=4.0, est=4.186377668376345, details={'was_impossible': False}),
#  Prediction(uid='105-S3J', iid=247766478, r_ui=4.0, est=3.4682822498690085, details={'was_impossible': False}),
#  Prediction(uid='5-Team Rick', iid=472774192, r_ui=1.0, est=3.3836547911609984, details={'was_impossible': False}),
#  Prediction(uid='19-Data in Destiny', iid=471628000, r_ui=4.0, est=3.291234259260975, details={'was_impossible': False}),
#  Prediction(uid='101-S3J', iid=2795232150, r_ui=3.0, est=3.4472049776689464, details={'was_impossible': False}),
#  Prediction(uid='U15-Data Bunny', iid=9708663946, r_ui=4.0, est=3.865696129673721, details={'was_impossible': False}),
#  Prediction(uid='U19-Data Bunny', iid=359687037, r_ui=4.0, est=3.880164577080471, details={'was_impossible': False}),
#  Prediction(uid='8-Team Rick', iid=4985409623, r_ui=3.0, est=2.963949295130433, details={'was_impossible': False}),
#  Prediction(uid='116-S3J', iid=247766478, r_ui=2.0, est=3.544706337608617, details={'was_impossible': False}),
#  Prediction(uid='104-S3J', iid=4095987426, r_ui=3.0, est=3.4159606270071343, details={'was_impossible': False}),
#  Prediction(uid='3-Kool and the floating point', iid=41217199, r_ui=3.0, est=3.4060789875091606, details={'was_impossible': False}),
#  Prediction(uid='18-Data in Destiny', iid=405400186, r_ui=4.0, est=3.958328119223383, details={'was_impossible': False}),
#  Prediction(uid='16-Team21', iid=4127859153, r_ui=4.0, est=3.698709915126207, details={'was_impossible': False}),
#  Prediction(uid='6-Data in Destiny', iid=4095400151, r_ui=5.0, est=3.7599075246854654, details={'was_impossible': False}),
#  Prediction(uid='8-Kool and the floating point', iid=564888514, r_ui=4.0, est=3.7055936036656303, details={'was_impossible': False}),
#  Prediction(uid='3-Kool and the floating point', iid=246249861, r_ui=3.0, est=3.0157805626153276, details={'was_impossible': False}),
#  Prediction(uid='1-Data in Destiny', iid=534917835, r_ui=4.0, est=3.733048324842649, details={'was_impossible': False}),
#  Prediction(uid='1-Data in Destiny', iid=534878149, r_ui=4.0, est=3.886988006739346, details={'was_impossible': False}),
#  Prediction(uid='7-Team Rick', iid=359691979, r_ui=4.0, est=4.352545498546549, details={'was_impossible': False}),
#  Prediction(uid='20-Team Rick', iid=9581108183, r_ui=4.0, est=3.6821366873490873, details={'was_impossible': False}),
#  Prediction(uid='6-Kool and the floating point', iid=4095400151, r_ui=4.0, est=3.455377613648257, details={'was_impossible': False}),
#  Prediction(uid='103-S3J', iid=49023482, r_ui=4.0, est=3.6228597586220745, details={'was_impossible': False}),
#  Prediction(uid='1-Data in Destiny', iid=359694751, r_ui=4.0, est=3.704135523242899, details={'was_impossible': False}),
#  Prediction(uid='9-Team21', iid=9813646886, r_ui=4.0, est=3.870382670688086, details={'was_impossible': False})]

# %%
# predictions = algo.test(testset)
precisions, recalls = s_utils.precision_recall_at_k(predictions, k=5, threshold=4)

# %%
len(precisions)
# Out:
# 86

# %%
print(sum(prec for prec in precisions.values()) / len(precisions))
print(sum(rec for rec in recalls.values()) / len(recalls))
# Out:
# 0.2558139534883721
# 0.22093023255813954

# %%
# testset = trainset.build_anti_testset()
predictions = algo.test(testset)

top_n = s_utils.get_top_n(predictions, n=5)

# Print the recommended items for each user
for uid, user_ratings in top_n.items():
    print(uid, [iid for (iid, _) in user_ratings])
# Out:
# U5-Data Bunny [359694784, 256866280, 659475608]
# 6-Kool and the floating point [564888514, 277746978, 4095400151, 359693315]
# 10-Kool and the floating point [7503079102, 4816412579]
# U16-Data Bunny [359694784, 472774192, 43011471]
# U12-Data Bunny [256866280, 246253651]
# 108-S3J [731833436, 359686907, 561504426]
# 115-S3J [6223030513]
# 12-Kool and the floating point [359687037, 2466736061, 7503079102, 135915056]
# 9-Team Rick [359686907, 1519474203]
# 3-Team21 [359695274, 1519474203, 4127859153, 703057903]
# U15-Data Bunny [9708663946, 282655574, 43011471]
# 13-Team Rick [76852026291]
# U4-Data Bunny [7439496294, 574685031, 353186982]
# 18-Data in Destiny [380094845, 2466736061, 405400186]
# 12-Team Rick [1479407508, 7503079102, 282655574]
# 107-S3J [4095987422, 854335396]
# 19-Team Rick [9581108183]
# 14-Team Rick [76852026291, 359686907, 471628000, 353186982]
# U7-Data Bunny [564888543, 4095400186]
# U9-Data Bunny [270908998, 380488748]
# 2-Team21 [282655581, 703057903]
# 20-Data in Destiny [380094845]
# 11-Team21 [282655581]
# 112-S3J [270908998, 5144542839]
# 116-S3J [472774192, 247766478, 282655574]
# U2-Data Bunny [9655661536, 353186982]
# 4-Team21 [359695274, 4127859153]
# 16-Data in Destiny [41217199]
# 7-Data in Destiny [7439496294]
# U17-Data Bunny [6223030513, 763523652]
# 11-Kool and the floating point [7503079102, 8128785390, 471628000]
# 8-Team21 [1519474203]
# 1-Team Rick [353186982]
# 111-S3J [359694784, 2466736061]
# 104-S3J [6223030513, 4095400186, 472774192, 2424718821, 4095987426]
# 1-Team21 [359695274, 4095400186, 8199027204]
# 16-Team Rick [76852026291]
# 4-Team Rick [2466736061]
# 9-Team21 [4095400186, 9813646886, 5109346567]
# 20-Team Rick [471628000, 9581108183]
# 6-Data in Destiny [4095400151, 564670042]
# 4-Kool and the floating point [4395329792]
# 15-Team21 [359695274, 4127859153]
# 22-Data in Destiny [359685942]
# 17-Data in Destiny [534878149]
# 7-Team Rick [359691979, 359686638, 763523652]
# 10-Data in Destiny [9880301426, 2424724937]
# 9-Kool and the floating point [4095400186, 6223030513, 2466736061]
# U14-Data Bunny [270908998]
# 114-S3J [6223030513, 2466736061, 472774192, 380488748, 246249861]
# 14-Data in Destiny [359691092, 2570468652]
# 5-Team Rick [359695274, 4456693165, 472774192, 4127859153, 3483494147]
# 7-Kool and the floating point [4095400186]
# 101-S3J [4095987428, 277746978, 561524250, 2795232150]
# U1-Data Bunny [8128785390]
# 9-Data in Destiny [2424724937, 712608636, 534876365]
# 2-Data in Destiny [359686638, 534917835, 359683717]
# 20-Team21 [8199027204]
# 8-Data in Destiny [7439496294]
# 3-Data in Destiny [4109460415, 7826688994]
# 113-S3J [6223030513]
# 3-Kool and the floating point [41217199, 359688178, 246249861]
# 100-S3J [6504247617, 561524250]
# 8-Team Rick [9655661531, 3483494147, 4985409623]
# 7-Team21 [4127859153]
# 15-Data in Destiny [47162000, 246249861]
# 2-Team Rick [2795251539]
# 4-Data in Destiny [1519474203, 8128785390, 8519878955]
# U19-Data Bunny [359687037, 359691092]
# U10-Data Bunny [9655661535]
# 11-Team Rick [359686907]
# 3-Team Rick [4358977790]
# U6-Data Bunny [7992692128]
# 19-Data in Destiny [1519474203, 471628000]
# 12-Team21 [359695274]
# 105-S3J [2424718821, 247766478]
# U11-Data Bunny [359691092]
# U20-Data Bunny [359690786]
# 1-Data in Destiny [534878149, 2424724937, 534917835, 359694751]
# 106-S3J [472774192]
# 110-S3J [256866280]
# 6-Team Rick [2493971952]
# 103-S3J [9655661536, 49023482]
# 5-Data in Destiny [1519474203]
# 16-Team21 [4127859153]
# 8-Kool and the floating point [564888514]

# %%
top_n
# Out:
# defaultdict(list,
#             {'U5-Data Bunny': [(359694784, 4.213136498013448),
#               (256866280, 4.140649067144969),
#               (659475608, 4.004185641660566)],
#              '6-Kool and the floating point': [(564888514, 3.8048099022841475),
#               (277746978, 3.6889426182556653),
#               (4095400151, 3.455377613648257),
#               (359693315, 2.8108507714245956)],
#              '10-Kool and the floating point': [(7503079102,
#                3.5231903624904954),
#               (4816412579, 3.5197522955900262)],
#              'U16-Data Bunny': [(359694784, 3.7982552072420317),
#               (472774192, 3.7770414447711866),
#               (43011471, 3.195964086010014)],
#              'U12-Data Bunny': [(256866280, 3.8616633685575374),
#               (246253651, 3.769639572017036)],
#              '108-S3J': [(731833436, 3.8611087603574545),
#               (359686907, 3.6850521744322804),
#               (561504426, 3.27854248466876)],
#              '115-S3J': [(6223030513, 3.521205219443351)],
#              '12-Kool and the floating point': [(359687037, 4.219129540768112),
#               (2466736061, 4.118115782291297),
#               (7503079102, 3.9561924084506157),
#               (135915056, 3.9561924084506157)],
#              '9-Team Rick': [(359686907, 3.674302689111335),
#               (1519474203, 3.530828827085279)],
#              '3-Team21': [(359695274, 3.9276358173885315),
#               (1519474203, 3.8850680365658072),
#               (4127859153, 3.8314378939144267),
#               (703057903, 3.754664343897384)],
#              'U15-Data Bunny': [(9708663946, 3.865696129673721),
#               (282655574, 3.7189081087595044),
#               (43011471, 3.503700244775937)],
#              '13-Team Rick': [(76852026291, 3.705717540184578)],
#              'U4-Data Bunny': [(7439496294, 3.8642159393725004),
#               (574685031, 3.68508677991173),
#               (353186982, 3.6494914472930136)],
#              '18-Data in Destiny': [(380094845, 4.128040119050934),
#               (2466736061, 4.115233083767771),
#               (405400186, 3.958328119223383)],
#              '12-Team Rick': [(1479407508, 4.227282808041476),
#               (7503079102, 4.038865098820536),
#               (282655574, 3.9081870968254493)],
#              '107-S3J': [(4095987422, 3.8979718408326165),
#               (854335396, 3.2197547488847973)],
#              '19-Team Rick': [(9581108183, 3.537155592694059)],
#              '14-Team Rick': [(76852026291, 4.015272902324025),
#               (359686907, 3.7806470249558624),
#               (471628000, 3.5698492650936586),
#               (353186982, 3.5435856300235016)],
#              'U7-Data Bunny': [(564888543, 4.61405424859896),
#               (4095400186, 4.531460859108714)],
#              'U9-Data Bunny': [(270908998, 4.4692925209046095),
#               (380488748, 4.3903105706599295)],
#              '2-Team21': [(282655581, 4.117885934010465),
#               (703057903, 3.592541034302999)],
#              '20-Data in Destiny': [(380094845, 3.9258740955498728)],
#              '11-Team21': [(282655581, 4.225185369960557)],
#              '112-S3J': [(270908998, 3.7908287682689057),
#               (5144542839, 3.671588986366617)],
#              '116-S3J': [(472774192, 3.869078123739632),
#               (247766478, 3.544706337608617),
#               (282655574, 3.2959765881875844)],
#              'U2-Data Bunny': [(9655661536, 3.8333731606658437),
#               (353186982, 3.524611465046949)],
#              '4-Team21': [(359695274, 4.11741805463399),
#               (4127859153, 3.934171734355484)],
#              '16-Data in Destiny': [(41217199, 3.687090537440542)],
#              '7-Data in Destiny': [(7439496294, 4.225596151220224)],
#              'U17-Data Bunny': [(6223030513, 4.462897473367505),
#               (763523652, 4.121080426824136)],
#              '11-Kool and the floating point': [(7503079102,
#                3.7436911061770726),
#               (8128785390, 3.525080123695106),
#               (471628000, 3.51482363721561)],
#              '8-Team21': [(1519474203, 3.8844177348284727)],
#              '1-Team Rick': [(353186982, 3.277967209575046)],
#              '111-S3J': [(359694784, 4.2460668419478615),
#               (2466736061, 3.8180310190755122)],
#              '104-S3J': [(6223030513, 3.8768778593303126),
#               (4095400186, 3.6248082593081143),
#               (472774192, 3.602988396031492),
#               (2424718821, 3.4255013866643584),
#               (4095987426, 3.4159606270071343)],
#              '1-Team21': [(359695274, 3.885131148761638),
#               (4095400186, 3.869584781736317),
#               (8199027204, 3.7737425290431)],
#              '16-Team Rick': [(76852026291, 3.7124168477523325)],
#              '4-Team Rick': [(2466736061, 3.943421467588674)],
#              '9-Team21': [(4095400186, 3.9678644225322826),
#               (9813646886, 3.870382670688086),
#               (5109346567, 3.855403143461231)],
#              '20-Team Rick': [(471628000, 3.6921904394856067),
#               (9581108183, 3.6821366873490873)],
#              '6-Data in Destiny': [(4095400151, 3.7599075246854654),
#               (564670042, 3.6965206224268825)],
#              '4-Kool and the floating point': [(4395329792,
#                3.228430144514353)],
#              '15-Team21': [(359695274, 4.161569199415703),
#               (4127859153, 3.72608270993877)],
#              '22-Data in Destiny': [(359685942, 3.6464198709730713)],
#              '17-Data in Destiny': [(534878149, 4.145020153201753)],
#              '7-Team Rick': [(359691979, 4.352545498546549),
#               (359686638, 4.250972478363887),
#               (763523652, 4.126653039200348)],
#              '10-Data in Destiny': [(9880301426, 4.14415855575664),
#               (2424724937, 4.059246503082317)],
#              '9-Kool and the floating point': [(4095400186,
#                3.8887019988136826),
#               (6223030513, 3.8788913434414365),
#               (2466736061, 3.6613589715573123)],
#              'U14-Data Bunny': [(270908998, 3.6057963732365947)],
#              '114-S3J': [(6223030513, 3.608733088345813),
#               (2466736061, 3.603015006045113),
#               (472774192, 3.3355715099198497),
#               (380488748, 3.315587217662561),
#               (246249861, 3.1780112983937303)],
#              '14-Data in Destiny': [(359691092, 4.146356139388117),
#               (2570468652, 4.094405367852663)],
#              '5-Team Rick': [(359695274, 3.7207261323220067),
#               (4456693165, 3.533028203804048),
#               (472774192, 3.3836547911609984),
#               (4127859153, 3.2467135847383486),
#               (3483494147, 2.999020483465128)],
#              '7-Kool and the floating point': [(4095400186,
#                3.9778102402287847)],
#              '101-S3J': [(4095987428, 4.0150867537649955),
#               (277746978, 3.578342080493787),
#               (561524250, 3.5774855336503695),
#               (2795232150, 3.4472049776689464)],
#              'U1-Data Bunny': [(8128785390, 3.4667658646718995)],
#              '9-Data in Destiny': [(2424724937, 3.8339706147233104),
#               (712608636, 3.823281233400239),
#               (534876365, 3.7568713440905768)],
#              '2-Data in Destiny': [(359686638, 4.046325094737311),
#               (534917835, 3.946624629488429),
#               (359683717, 3.920901865369496)],
#              '20-Team21': [(8199027204, 3.7032597365378734)],
#              '8-Data in Destiny': [(7439496294, 3.5519257578888563)],
#              '3-Data in Destiny': [(4109460415, 3.7458605769168236),
#               (7826688994, 3.6305373218306114)],
#              '113-S3J': [(6223030513, 3.8314783399071084)],
#              '3-Kool and the floating point': [(41217199, 3.4060789875091606),
#               (359688178, 3.306538708631484),
#               (246249861, 3.0157805626153276)],
#              '100-S3J': [(6504247617, 4.031135460949735),
#               (561524250, 3.98968919442219)],
#              '8-Team Rick': [(9655661531, 3.4216254604820366),
#               (3483494147, 3.247378606927331),
#               (4985409623, 2.963949295130433)],
#              '7-Team21': [(4127859153, 3.920991218568937)],
#              '15-Data in Destiny': [(47162000, 3.7274600373760363),
#               (246249861, 3.33926521134475)],
#              '2-Team Rick': [(2795251539, 4.100540484374868)],
#              '4-Data in Destiny': [(1519474203, 4.223072046870893),
#               (8128785390, 4.042380041256258),
#               (8519878955, 3.914662871543973)],
#              'U19-Data Bunny': [(359687037, 3.880164577080471),
#               (359691092, 3.868399110383821)],
#              'U10-Data Bunny': [(9655661535, 3.713371396014506)],
#              '11-Team Rick': [(359686907, 4.021810409829128)],
#              '3-Team Rick': [(4358977790, 3.6497909319826873)],
#              'U6-Data Bunny': [(7992692128, 4.301032298184535)],
#              '19-Data in Destiny': [(1519474203, 3.6223796886647266),
#               (471628000, 3.291234259260975)],
#              '12-Team21': [(359695274, 4.161696751724358)],
#              '105-S3J': [(2424718821, 3.5406792851642477),
#               (247766478, 3.4682822498690085)],
#              'U11-Data Bunny': [(359691092, 3.9752054366993903)],
#              'U20-Data Bunny': [(359690786, 3.757250559189612)],
#              '1-Data in Destiny': [(534878149, 3.886988006739346),
#               (2424724937, 3.754019051696568),
#               (534917835, 3.733048324842649),
#               (359694751, 3.704135523242899)],
#              '106-S3J': [(472774192, 4.0486148135486015)],
#              '110-S3J': [(256866280, 3.915392869689416)],
#              '6-Team Rick': [(2493971952, 3.600519197360637)],
#              '103-S3J': [(9655661536, 4.0279138946763196),
#               (49023482, 3.6228597586220745)],
#              '5-Data in Destiny': [(1519474203, 4.186377668376345)],
#              '16-Team21': [(4127859153, 3.698709915126207)],
#              '8-Kool and the floating point': [(564888514,
#                3.7055936036656303)]})

# %%
new user
retrain
get the top n recommendations for those neighbours

# %%
df
# Out:
#            USER_ID      OSM_ID  RATING
# 0    U1-Data Bunny   353186982       4
# 1    U1-Data Bunny  8128785390       2
# 2    U1-Data Bunny  7439496294       1
# 3    U1-Data Bunny  7439496294       4
# 4    U2-Data Bunny   359687975       4
# ..             ...         ...     ...
# 876      17-Team21  4486137546       4
# 877      19-Team21   359695274       3
# 878      19-Team21  8199027204       3
# 879      20-Team21   359695274       4
# 880      20-Team21  8199027204       4
#
# [881 rows x 3 columns]

# %%
df_new_user = pd.DataFrame({'USER_ID': ['new_user', 'new_user', 'new_user'],
                            'OSM_ID': [76852026291, 359686907, 471628000], 
                            'RATING': [5, 5, 5]
                           }
                          )

# df_total = df.append(df_new_user, ignore_index=True)
df_tmp = pd.concat([df, df_new_user], ignore_index = True)
# df_total.reset_index()

# %%
df_total
# Out:
#            USER_ID       OSM_ID  RATING
# 0    U1-Data Bunny    353186982       4
# 1    U1-Data Bunny   8128785390       2
# 2    U1-Data Bunny   7439496294       1
# 3    U1-Data Bunny   7439496294       4
# 4    U2-Data Bunny    359687975       4
# ..             ...          ...     ...
# 879      20-Team21    359695274       4
# 880      20-Team21   8199027204       4
# 881       new_user  76852026291       5
# 882       new_user    359686907       5
# 883       new_user    471628000       5
#
# [884 rows x 3 columns]

# %%
data_tmp = Dataset.load_from_df(df_total[["USER_ID", "OSM_ID", "RATING"]], reader)

# %%
algo_tmp = SVD()
trainset_tmp = data_tmp.build_full_trainset()
algo_tmp.fit(trainset_tmp)

#predictions_new_user = algo_tmp.predict(uid, iid, r_ui=None, clip=True, verbose=False)

# Then predict ratings for all pairs (u, i) that are NOT in the training set.
anti_testset_tmp = trainset_tmp.build_anti_testset()
predictions_tmp = algo_tmp.test(anti_testset_tmp)

top_n_tmp = s_utils.get_top_n(predictions_tmp, n=5)

# %%
top_n_tmp['new_user']
# Out:
# [(6223030513, 4.736568163449599),
#  (359687975, 4.546574060498998),
#  (4095987419, 4.514561857823522),
#  (4434577593, 4.513280053757089),
#  (359694784, 4.50174913545392)]

# %%
bla = []
for u, item_ratings in top_n_tmp.items():
    for item, rating in item_ratings:
        bla.append([u, item, rating])

# %%
pd.DataFrame(bla, columns=['USER_ID', 'ITEM_ID', 'RATING'])
# Out:
#            USER_ID     ITEM_ID    RATING
# 0    U1-Data Bunny  6223030513  4.210050
# 1    U1-Data Bunny  4434577593  4.125262
# 2    U1-Data Bunny   359686638  3.971164
# 3    U1-Data Bunny   359687975  3.950164
# 4    U1-Data Bunny  4095400186  3.900128
# ..             ...         ...       ...
# 555       new_user  6223030513  4.736568
# 556       new_user   359687975  4.546574
# 557       new_user  4095987419  4.514562
# 558       new_user  4434577593  4.513280
# 559       new_user   359694784  4.501749
#
# [560 rows x 3 columns]

# %%
pd.DataFrame(top_n_tmp)
# Out:
#                       U1-Data Bunny                     U2-Data Bunny  \
# 0   (6223030513, 4.210049705643355)    (256866280, 4.141171734976134)
# 1   (4434577593, 4.125262229132057)   (282655581, 3.9876514070273363)
# 2    (359686638, 3.971164141612961)  (6223030513, 3.9724082097545144)
# 3   (359687975, 3.9501643604386665)  (4095987419, 3.8656477212810105)
# 4  (4095400186, 3.9001282083842854)   (369825427, 3.8482031461881423)
#
#                      U3-Data Bunny                    U4-Data Bunny  \
# 0  (6223030513, 4.520904481669662)  (6223030513, 4.677453475894925)
# 1  (4095987419, 4.315206518886112)   (256866280, 4.631672091927025)
# 2   (359695274, 4.301687472883813)  (4095987424, 4.468860155636384)
# 3   (560157037, 4.293099806268862)  (4095987419, 4.423433118245608)
# 4   (359687975, 4.264703729733945)   (4434577593, 4.39364948924547)
#
#                       U5-Data Bunny                    U6-Data Bunny  \
# 0   (6223030513, 4.484484076464255)  (6223030513, 4.500488825624482)
# 1   (4434577593, 4.427189430732434)   (4434577593, 4.44017454521395)
# 2    (359687975, 4.390838602362455)   (564888514, 4.364418774710649)
# 3   (9655661535, 4.324742137966524)   (256866280, 4.324386852073746)
# 4  (4095987419, 4.3177272809284855)   (498891528, 4.317552437513661)
#
#                      U7-Data Bunny                     U8-Data Bunny  \
# 0   (256866280, 4.806635137535432)  (6223030513, 4.3792065709660495)
# 1  (4434577593, 4.806123101760217)  (4095987422, 4.2841665592203135)
# 2  (4095987419, 4.773580812495828)    (498891528, 4.214019601857021)
# 3   (534878149, 4.768654740105913)    (359694784, 4.213022912683253)
# 4  (6223030513, 4.754182212968831)    (359687975, 4.204955767080571)
#
#                      U9-Data Bunny                    U10-Data Bunny  ...  \
# 0  (4434577593, 4.805647022615433)   (6223030513, 4.042237773744769)  ...
# 1   (359686638, 4.773930972765266)   (4434577593, 4.002780506484053)  ...
# 2  (4095987419, 4.695684337310117)    (359695274, 3.944201416716761)  ...
# 3  (6223030513, 4.683626881551704)   (359686638, 3.9210725720743786)  ...
# 4   (256866280, 4.682496431952673)  (9813646886, 3.9066480127694336)  ...
#
#                          11-Team21                        12-Team21  \
# 0   (256866280, 4.240259894909435)  (6223030513, 4.346625710479949)
# 1  (4434577593, 4.166472631702044)   (256866280, 4.037364326612054)
# 2   (380488748, 4.151063109730835)  (9655661535, 4.010784858853815)
# 3  (6223030513, 4.145040274833909)    (498891528, 3.98707953156145)
# 4  (9655661535, 4.144024156867603)  (4095987419, 3.963019961555809)
#
#                          13-Team21                        14-Team21  \
# 0   (256866280, 4.327422635259509)   (256866280, 4.431241847868084)
# 1  (6223030513, 4.295954141051041)  (9655661535, 4.328161777159039)
# 2   (282655581, 4.265025647947657)  (6223030513, 4.269403411296697)
# 3  (4095987419, 4.157591497874724)   (564888543, 4.247160898162837)
# 4   (380488748, 4.148894422837941)  (498891528, 4.2447745264065855)
#
#                          15-Team21                         16-Team21  \
# 0  (6223030513, 4.359824402043575)   (6223030513, 4.416068959414806)
# 1  (4095987419, 4.339937013904146)    (256866280, 4.212455940284786)
# 2   (282655581, 4.337419981964846)   (4095987419, 4.211640278371585)
# 3    (256866280, 4.31362134813561)    (9655661535, 4.17487238073402)
# 4   (359694784, 4.266381323042245)  (4434577593, 4.1664278669807855)
#
#                          17-Team21                        19-Team21  \
# 0   (4095987419, 4.30252705014796)   (256866280, 4.213698527544506)
# 1  (256866280, 4.2733838183980035)  (9655661535, 4.072661191254685)
# 2  (4095400186, 4.208746003460079)  (4434577593, 4.053277027932539)
# 3   (6223030513, 4.20530507272088)  (4095987419, 4.030657242202946)
# 4  (4434577593, 4.147449610384641)   (498891528, 4.005171880025994)
#
#                          20-Team21                         new_user
# 0  (6223030513, 4.224983601604321)  (6223030513, 4.736568163449599)
# 1  (4095987419, 4.207457169139077)   (359687975, 4.546574060498998)
# 2   (534878149, 4.195665667081286)  (4095987419, 4.514561857823522)
# 3    (256866280, 4.18480816509312)  (4434577593, 4.513280053757089)
# 4  (4095987422, 4.182984300902256)    (359694784, 4.50174913545392)
#
# [5 rows x 112 columns]
